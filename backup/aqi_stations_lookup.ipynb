# %%
'https://app.cpcbccr.com/aqi_dashboard/download?filename=AQI_all_station2013_03_01T16_00_00Z.xlsx'

# %%
import json
import requests
# %config Completer.use_jedi = False

# %%
res
# Out:
# <Response [304]>

# %%
filename = 'AQI_all_station2022_04_06T16_00_00Z.xlsx'

base_url = 'https://app.cpcbccr.com/aqi_dashboard/download?filename={}'.format(filename)

data_header = {
'authority': 'app.cpcbccr.com',
'method': 'GET',
'path': '/aqi_dashboard/download?filename={}'.format(filename),
'scheme': 'https',
'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
'accept-encoding': 'gzip, deflate, br',
'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
'cookie': '_xsrf=cfe36530bf7a4e41be432779feaf0c5f; ccr_captcha=""; ccr_public=""; _ga=GA1.2.1356179253.1680779755; _gid=GA1.2.1106396197.1680779755',
'referer': 'https://app.cpcbccr.com/AQI_India/',
'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
'sec-ch-ua-mobile': '?0',
'sec-ch-ua-platform': '"Linux"',
'sec-fetch-dest': 'iframe',
'sec-fetch-mode': 'navigate',
'sec-fetch-site': 'same-origin',
'sec-fetch-user': '?1',
'upgrade-insecure-requests': '1',
'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'
}

payload = {'filename': '{}'.format(filename)}

res = requests.get(base_url, headers=data_header, data=json.dumps(payload))

# %%
res.status_code
# Out:
# 500

# %%
with open('text.xlsx', 'wb') as fp:
    fp.write(res.content)

# %%
res.content
# Out:
# b'Internal Server Error'

# %%
session = requests.Session()

headers = {
'authority': 'app.cpcbccr.com',
'method': 'GET',
'path': '/AQI_India/',
'scheme': 'https',
'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
'accept-encoding': 'gzip, deflate, br',
'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
'cache-control': 'max-age=0',
'cookie': '_xsrf=cfe36530bf7a4e41be432779feaf0c5f; ccr_captcha=""; ccr_public=""; _ga=GA1.2.1356179253.1680779755; _gid=GA1.2.1106396197.1680779755; _gat=1',
'if-modified-since': 'Wed, 26 Oct 2022 12:41:48 GMT',
'if-none-match': 'W/"63592b0c-68ee"',
'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
'sec-ch-ua-mobile': '?0',
'sec-ch-ua-platform': '"Linux"',
'sec-fetch-dest': 'document',
'sec-fetch-mode': 'navigate',
'sec-fetch-site': 'none',
'sec-fetch-user': '?1',
'upgrade-insecure-requests': '1',
'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'
    }


url = "https://app.cpcbccr.com/AQI_India/"
res = requests.get(url, headers=headers)
# print(res.content)

# %%
res
# Out:
# <Response [304]>

# %%
header = {
'authority': 'app.cpcbccr.com',
'method': 'POST',
'path': '/aqi_dashboard/aqi_all_parameter_excel',
'scheme': 'https',
'accept': 'text/plain, */*; q=0.01',
'accept-encoding': 'gzip, deflate, br',
'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
'accesstoken': 'eyJ0aW1lIjoxNjgwNzgzNjk1MDA2LCJ0aW1lWm9uZU9mZnNldCI6LTMzMH0=',
'content-length': '76',
'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
'cookie': '_xsrf=cfe36530bf7a4e41be432779feaf0c5f; _ga=GA1.2.1356179253.1680779755; _gid=GA1.2.1106396197.1680779755; _gat=1; ccr_captcha=""; ccr_public=""',
'origin': 'https://app.cpcbccr.com',
'referer': 'https://app.cpcbccr.com/AQI_India/',
'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
'sec-ch-ua-mobile': '?0',
'sec-ch-ua-platform': '"Linux"',
'sec-fetch-dest': 'empty',
'sec-fetch-mode': 'cors',
'sec-fetch-site': 'same-origin',
'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

url = 'https://app.cpcbccr.com/aqi_dashboard/aqi_all_parameter_excel'
payload = 'eyJzdGF0aW9uX2lkIjoic2l0ZV8zMDEiLCJkYXRlIjoiMjAyMy0wNC0wNlQxNzowMDowMFoifQ: ='

res = requests.post(url, headers=header, data=json.dumps(payload))

# %%
res
# Out:
# <Response [200]>

# %%
filename = 'AQI_all_station2013_12_01T17_00_00Z.xlsx'

header = {
'authority': 'app.cpcbccr.com',
'method': 'GET',
'path': '/aqi_dashboard/download?filename={}'.format(filename),
'scheme': 'https',
'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
'accept-encoding': 'gzip, deflate, br',
'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
'cookie': '_xsrf=cfe36530bf7a4e41be432779feaf0c5f; _ga=GA1.2.1356179253.1680779755; _gid=GA1.2.1106396197.1680779755; _gat=1; ccr_captcha=""; ccr_public=""',
'referer': 'https://app.cpcbccr.com/AQI_India/',
'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
'sec-ch-ua-mobile': '?0',
'sec-ch-ua-platform': '"Linux"',
'sec-fetch-dest': 'iframe',
'sec-fetch-mode': 'navigate',
'sec-fetch-site': 'same-origin',
'sec-fetch-user': '?1',
'upgrade-insecure-requests': '1',
'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

payload = {'filename': '{}'.format(filename)}

url = 'https://app.cpcbccr.com/aqi_dashboard/download?filename={}'.format(filename)

res = requests.get(url, headers=header, data=json.dumps(payload))

# %%
res
# Out:
# <Response [500]>

# %%
with open('text.xlsx', 'wb') as fp:
    fp.write(res.content)

# %%
url
# Out:
# 'https://app.cpcbccr.com/aqi_dashboard/download?filename=AQI_all_station2021_04_06T17_00_00Z.xlsx'

# %%
import os
import shutil

# %%
for year in range(13,24):
    os.mkdir(os.path.join('./processed_stations_establishment/20{}'.format(str(year))))

# %%
import glob

# %%
all_files = glob.glob("./stations_establishment_timeline/*/*")

# %%
for file in all_files:
    print(file)
    new_filename = '20' + file.split('/')[-1][:-5].split('20')[1].split('T')[0]
    new_filename = '_'.join(new_filename.split('_')[::-1])
    new_loc = './processed_' + file.split("/")[1] + '/' +file.split('/')[2] + '/' + new_filename + '.csv'
    
    df = pd.read_excel(file, engine='openpyxl', skiprows=[0,1], header=[1],index_col=[0])
    df.fillna(method='ffill',inplace=True)
    df.to_csv(new_loc)
#     break
# Out:
# ./stations_establishment_timeline/2019/AQI_all_station2019_07_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_10_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_05_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_11_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_09_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_08_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_12_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_01_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_03_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_06_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_02_01T17_00_00Z.xlsx
# ./stations_establishment_timeline/2019/AQI_all_station2019_04_01T17_00_00Z.xlsx
# ...

# %%
df = pd.read_csv("./processed_stations_establishment_timeline/2023/01_01_2023.csv")

# %%
df
# Out:
#      S.No.           State               City  \
# 0        1  Andhra Pradesh          Amaravati
# 1        2             NaN          Anantapur
# 2        3             NaN           Chittoor
# 3        4             NaN             Kadapa
# 4        5             NaN  Rajamahendravaram
# ..     ...             ...                ...
# 423    424             NaN                NaN
# 424    425             NaN                NaN
# 425    426             NaN                NaN
# 426    427             NaN                NaN
# 427    428             NaN           Siliguri
#
#                                        Station Name  \
# 0                    Secretariat, Amaravati - APPCB
# 1                      Gulzarpet, Anantapur - APPCB
# 2               Gangineni Cheruvu, Chittoor - APPCB
# 3                   Yerramukkapalli, Kadapa - APPCB
# 4    Anand Kala Kshetram, Rajamahendravaram - APPCB
# ..                                              ...
# ...

# %%
df.fillna(method='ffill',inplace=True)

# %%
df.to_csv("./text.csv")

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Stations list with parameters

# %%
# taken from https://app.cpcbccr.com/ccr/#/caaqm-dashboard-all/caaqm-landing/data
# base64 decoded

raw_data = '{"cities": [{"stateName": "Karnataka", "citiesInState": [{"name": "Bagalkot", "live": true}, {"name": "Belgaum", "live": true}, {"name": "Bengaluru", "live": true}, {"name": "Bidar", "live": true}, {"name": "Chamarajanagar", "live": true}, {"name": "Chikkaballapur", "live": true}, {"name": "Chikkamagaluru", "live": true}, {"name": "Davanagere", "live": true}, {"name": "Dharwad", "live": true}, {"name": "Gadag", "live": true}, {"name": "Hassan", "live": true}, {"name": "Haveri", "live": true}, {"name": "Hubballi", "live": true}, {"name": "Kalaburagi", "live": true}, {"name": "Kolar", "live": true}, {"name": "Koppal", "live": true}, {"name": "Madikeri", "live": true}, {"name": "Mangalore", "live": true}, {"name": "Mysuru", "live": true}, {"name": "Raichur", "live": true}, {"name": "Ramanagara", "live": true}, {"name": "Shivamogga", "live": true}, {"name": "Tumakuru", "live": true}, {"name": "Udupi", "live": true}, {"name": "Vijayapura", "live": true}, {"name": "Yadgir", "live": true}]}, {"stateName": "Madhya Pradesh", "citiesInState": [{"name": "Bhopal", "live": true}, {"name": "Damoh", "live": true}, {"name": "Dewas", "live": true}, {"name": "Gwalior", "live": true}, {"name": "Indore", "live": true}, {"name": "Jabalpur", "live": true}, {"name": "Katni", "live": true}, {"name": "Maihar", "live": true}, {"name": "Mandideep", "live": true}, {"name": "Pithampur", "live": true}, {"name": "Ratlam", "live": true}, {"name": "Sagar", "live": true}, {"name": "Satna", "live": true}, {"name": "Singrauli", "live": true}, {"name": "Ujjain", "live": true}]}, {"stateName": "Uttar Pradesh", "citiesInState": [{"name": "Agra", "live": true}, {"name": "Baghpat", "live": true}, {"name": "Bareilly", "live": true}, {"name": "Bulandshahr", "live": true}, {"name": "Firozabad", "live": true}, {"name": "Ghaziabad", "live": true}, {"name": "Gorakhpur", "live": true}, {"name": "Greater Noida", "live": true}, {"name": "Hapur", "live": true}, {"name": "Jhansi", "live": true}, {"name": "Kanpur", "live": true}, {"name": "Khurja", "live": true}, {"name": "Lucknow", "live": true}, {"name": "Meerut", "live": true}, {"name": "Moradabad", "live": true}, {"name": "Muzaffarnagar", "live": true}, {"name": "Noida", "live": true}, {"name": "Prayagraj", "live": true}, {"name": "Varanasi", "live": true}, {"name": "Vrindavan", "live": true}]}, {"stateName": "Gujarat", "citiesInState": [{"name": "Ahmedabad", "live": true}, {"name": "Ankleshwar", "live": true}, {"name": "Gandhinagar", "live": true}, {"name": "Nandesari", "live": true}, {"name": "Surat", "live": true}, {"name": "Vapi", "live": true}, {"name": "Vatva", "live": true}]}, {"stateName": "Delhi", "citiesInState": [{"name": "Delhi", "live": true}]}, {"stateName": "Tamil Nadu", "citiesInState": [{"name": "Ariyalur", "live": true}, {"name": "Chengalpattu", "live": true}, {"name": "Chennai", "live": true}, {"name": "Coimbatore", "live": true}, {"name": "Cuddalore", "live": true}, {"name": "Dindigul", "live": true}, {"name": "Gummidipoondi", "live": true}, {"name": "Hosur", "live": true}, {"name": "Kanchipuram", "live": true}, {"name": "Ooty", "live": true}, {"name": "Palkalaiperur", "live": true}, {"name": "Ramanathapuram", "live": true}, {"name": "Salem", "live": true}, {"name": "Thoothukudi", "live": true}, {"name": "Tirupur", "live": true}, {"name": "Vellore", "live": true}]}, {"stateName": "Maharashtra", "citiesInState": [{"name": "Aurangabad", "live": true}, {"name": "Chandrapur", "live": true}, {"name": "Kalyan", "live": true}, {"name": "Mumbai", "live": true}, {"name": "Nagpur", "live": true}, {"name": "Nashik", "live": true}, {"name": "Navi Mumbai", "live": true}, {"name": "Pune", "live": true}, {"name": "Solapur", "live": true}, {"name": "Thane", "live": true}]}, {"stateName": "Haryana", "citiesInState": [{"name": "Ambala", "live": true}, {"name": "Bahadurgarh", "live": true}, {"name": "Ballabgarh", "live": true}, {"name": "Bhiwani", "live": true}, {"name": "Charkhi Dadri", "live": true}, {"name": "Dharuhera", "live": true}, {"name": "Faridabad", "live": true}, {"name": "Fatehabad", "live": true}, {"name": "Gurugram", "live": true}, {"name": "Hisar", "live": true}, {"name": "Jind", "live": true}, {"name": "Kaithal", "live": true}, {"name": "Karnal", "live": true}, {"name": "Kurukshetra ", "live": true}, {"name": "Mandikhera", "live": true}, {"name": "Manesar", "live": true}, {"name": "Narnaul", "live": true}, {"name": "Palwal ", "live": true}, {"name": "Panchkula", "live": true}, {"name": "Panipat", "live": true}, {"name": "Rohtak", "live": true}, {"name": "Sirsa", "live": true}, {"name": "Sonipat", "live": true}, {"name": "Yamuna Nagar", "live": true}]}, {"stateName": "Andhra Pradesh", "citiesInState": [{"name": "Amaravati", "live": true}, {"name": "Anantapur", "live": true}, {"name": "Chittoor", "live": true}, {"name": "Kadapa", "live": true}, {"name": "Rajamahendravaram", "live": true}, {"name": "Tirupati", "live": true}, {"name": "Vijayawada", "live": true}, {"name": "Visakhapatnam", "live": true}]}, {"stateName": "West Bengal", "citiesInState": [{"name": "Asansol", "live": true}, {"name": "Durgapur", "live": true}, {"name": "Haldia", "live": true}, {"name": "Howrah", "live": true}, {"name": "Kolkata", "live": true}, {"name": "Siliguri", "live": true}]}, {"stateName": "Sikkim", "citiesInState": [{"name": "Gangtok", "live": true}]}, {"stateName": "Bihar", "citiesInState": [{"name": "Araria", "live": true}, {"name": "Arrah", "live": true}, {"name": "Aurangabad", "live": true}, {"name": "Begusarai", "live": true}, {"name": "Bettiah", "live": true}, {"name": "Bhagalpur", "live": true}, {"name": "Bihar Sharif", "live": true}, {"name": "Buxar", "live": true}, {"name": "Chhapra", "live": true}, {"name": "Darbhanga", "live": true}, {"name": "Gaya", "live": true}, {"name": "Hajipur", "live": true}, {"name": "Katihar", "live": true}, {"name": "Kishanganj", "live": true}, {"name": "Manguraha", "live": true}, {"name": "Motihari", "live": true}, {"name": "Munger", "live": true}, {"name": "Muzaffarpur", "live": true}, {"name": "Patna", "live": true}, {"name": "Purnia", "live": true}, {"name": "Rajgir", "live": true}, {"name": "Saharsa", "live": true}, {"name": "Samastipur", "live": true}, {"name": "Sasaram", "live": true}, {"name": "Siwan", "live": true}]}, {"stateName": "Chandigarh", "citiesInState": [{"name": "Chandigarh", "live": true}]}, {"stateName": "Telangana", "citiesInState": [{"name": "Hyderabad", "live": true}]}, {"stateName": "Rajasthan", "citiesInState": [{"name": "Ajmer", "live": true}, {"name": "Alwar", "live": true}, {"name": "Banswara", "live": true}, {"name": "Barmer", "live": true}, {"name": "Bharatpur", "live": true}, {"name": "Bhiwadi", "live": true}, {"name": "Bikaner", "live": true}, {"name": "Chittorgarh", "live": true}, {"name": "Churu", "live": true}, {"name": "Dausa", "live": true}, {"name": "Dholpur", "live": true}, {"name": "Hanumangarh", "live": true}, {"name": "Jaipur", "live": true}, {"name": "Jhalawar", "live": true}, {"name": "Jhunjhunu", "live": true}, {"name": "Jodhpur", "live": true}, {"name": "Karauli", "live": true}, {"name": "Kota", "live": true}, {"name": "Pali", "live": true}, {"name": "Pratapgarh", "live": true}, {"name": "Rajsamand", "live": true}, {"name": "Sawai Madhopur", "live": true}, {"name": "Sikar", "live": true}, {"name": "Sirohi", "live": true}, {"name": "Sri Ganganagar", "live": true}, {"name": "Tonk", "live": true}, {"name": "Udaipur", "live": true}]}, {"stateName": "Punjab", "citiesInState": [{"name": "Amritsar", "live": true}, {"name": "Bathinda", "live": true}, {"name": "Jalandhar", "live": true}, {"name": "Khanna", "live": true}, {"name": "Ludhiana", "live": true}, {"name": "Mandi Gobindgarh", "live": true}, {"name": "Patiala", "live": true}, {"name": "Rupnagar", "live": true}]}, {"stateName": "Kerala", "citiesInState": [{"name": "Eloor", "live": true}, {"name": "Ernakulam", "live": true}, {"name": "Kannur", "live": true}, {"name": "Kochi", "live": true}, {"name": "Kollam", "live": true}, {"name": "Kozhikode", "live": true}, {"name": "Thiruvananthapuram", "live": true}, {"name": "Thrissur", "live": true}]}, {"stateName": "Chhattisgarh", "citiesInState": [{"name": "Bhilai", "live": true}, {"name": "Bilaspur", "live": true}, {"name": "Chhal", "live": true}, {"name": "Korba", "live": true}, {"name": "Kunjemura", "live": true}, {"name": "Milupara", "live": true}, {"name": "Raipur", "live": true}, {"name": "Tumidih", "live": true}]}, {"stateName": "Odisha", "citiesInState": [{"name": "Baripada", "live": true}, {"name": "Bileipada", "live": true}, {"name": "Brajrajnagar", "live": true}, {"name": "Keonjhar", "live": true}, {"name": "Nayagarh", "live": true}, {"name": "Rairangpur", "live": true}, {"name": "Rourkela", "live": true}, {"name": "Suakati", "live": true}, {"name": "Talcher", "live": true}, {"name": "Tensa", "live": true}]}, {"stateName": "Assam", "citiesInState": [{"name": "Byrnihat", "live": true}, {"name": "Guwahati", "live": true}, {"name": "Nagaon", "live": true}, {"name": "Nalbari", "live": true}, {"name": "Silchar", "live": true}, {"name": "Sivasagar", "live": true}]}, {"stateName": "Uttarakhand", "citiesInState": [{"name": "Dehradun", "live": true}, {"name": "Kashipur", "live": true}, {"name": "Rishikesh", "live": true}]}, {"stateName": "Jammu and Kashmir", "citiesInState": [{"name": "Srinagar", "live": true}]}, {"stateName": "Tripura", "citiesInState": [{"name": "Agartala", "live": true}]}, {"stateName": "Jharkhand", "citiesInState": [{"name": "Dhanbad", "live": true}, {"name": "Jorapokhar", "live": true}]}, {"stateName": "Himachal Pradesh", "citiesInState": [{"name": "Baddi", "live": true}]}, {"stateName": "Meghalaya ", "citiesInState": [{"name": "Shillong", "live": true}]}, {"stateName": "Puducherry", "citiesInState": [{"name": "Puducherry", "live": true}]}, {"stateName": "Mizoram", "citiesInState": [{"name": "Aizawl", "live": true}]}, {"stateName": "Arunachal Pradesh", "citiesInState": [{"name": "Naharlagun", "live": true}]}, {"stateName": "Manipur", "citiesInState": [{"name": "Imphal", "live": true}]}, {"stateName": "Nagaland", "citiesInState": [{"name": "Kohima", "live": true}]}], "states": [{"name": "Andhra Pradesh", "live": true}, {"name": "Arunachal Pradesh", "live": true}, {"name": "Assam", "live": true}, {"name": "Bihar", "live": true}, {"name": "Chandigarh", "live": true}, {"name": "Chhattisgarh", "live": true}, {"name": "Delhi", "live": true}, {"name": "Gujarat", "live": true}, {"name": "Haryana", "live": true}, {"name": "Himachal Pradesh", "live": true}, {"name": "Jammu and Kashmir", "live": true}, {"name": "Jharkhand", "live": true}, {"name": "Karnataka", "live": true}, {"name": "Kerala", "live": true}, {"name": "Madhya Pradesh", "live": true}, {"name": "Maharashtra", "live": true}, {"name": "Manipur", "live": true}, {"name": "Meghalaya ", "live": true}, {"name": "Mizoram", "live": true}, {"name": "Nagaland", "live": true}, {"name": "Odisha", "live": true}, {"name": "Puducherry", "live": true}, {"name": "Punjab", "live": true}, {"name": "Rajasthan", "live": true}, {"name": "Sikkim", "live": true}, {"name": "Tamil Nadu", "live": true}, {"name": "Telangana", "live": true}, {"name": "Tripura", "live": true}, {"name": "Uttar Pradesh", "live": true}, {"name": "Uttarakhand", "live": true}, {"name": "West Bengal", "live": true}], "stations": [{"cityName": "Bengaluru", "stationsInCity": [{"id": "site_162", "name": "BTM Layout, Bengaluru - CPCB", "live": true}, {"id": "site_164", "name": "BWSSB Kadabesanahalli, Bengaluru - CPCB", "live": true}, {"id": "site_1553", "name": "Bapuji Nagar, Bengaluru - KSPCB", "live": true}, {"id": "site_165", "name": "City Railway Station, Bengaluru - KSPCB", "live": true}, {"id": "site_1554", "name": "Hebbal, Bengaluru - KSPCB", "live": true}, {"id": "site_1555", "name": "Hombegowda Nagar, Bengaluru - KSPCB", "live": true}, {"id": "site_1556", "name": "Jayanagar 5th Block, Bengaluru - KSPCB", "live": true}, {"id": "site_163", "name": "Peenya, Bengaluru - CPCB", "live": true}, {"id": "site_5678", "name": "RVCE-Mailasandra, Bengaluru - KSPCB", "live": true}, {"id": "site_166", "name": "Sanegurava Halli, Bengaluru - KSPCB", "live": true}, {"id": "site_5686", "name": "Shivapura_Peenya, Bengaluru - KSPCB", "live": true}, {"id": "site_1558", "name": "Silk Board, Bengaluru - KSPCB", "live": true}]}, {"cityName": "Yadgir", "stationsInCity": [{"id": "site_5254", "name": "Collector Office, Yadgir - KSPCB", "live": true}]}, {"cityName": "Gwalior", "stationsInCity": [{"id": "site_5273", "name": "City Center, Gwalior - MPPCB", "live": true}, {"id": "site_5667", "name": "Deen Dayal Nagar, Gwalior - MPPCB", "live": true}, {"id": "site_5661", "name": "Maharaj Bada, Gwalior - MPPCB", "live": true}, {"id": "site_5275", "name": "Phool Bagh, Gwalior - Mondelez Ind. Food", "live": true}]}, {"cityName": "Ghaziabad", "stationsInCity": [{"id": "site_5082", "name": "Indirapuram, Ghaziabad - UPPCB", "live": true}, {"id": "site_5083", "name": "Loni, Ghaziabad - UPPCB", "live": true}, {"id": "site_5081", "name": "Sanjay Nagar, Ghaziabad - UPPCB", "live": true}, {"id": "site_144", "name": "Vasundhara, Ghaziabad - UPPCB", "live": true}]}, {"cityName": "Ahmedabad", "stationsInCity": [{"id": "site_5453", "name": "Chandkheda, Ahmedabad - IITM", "live": true}, {"id": "site_5450", "name": "Gyaspur, Ahmedabad - IITM", "live": true}, {"id": "site_308", "name": "Maninagar, Ahmedabad - GPCB", "live": true}, {"id": "site_5452", "name": "Raikhad, Ahmedabad - IITM", "live": true}, {"id": "site_5451", "name": "Rakhial, Ahmedabad - IITM", "live": true}, {"id": "site_5454", "name": "SAC ISRO Bopal, Ahmedabad - IITM", "live": true}, {"id": "site_5455", "name": "SAC ISRO Satellite, Ahmedabad - IITM", "live": true}, {"id": "site_5456", "name": "SVPI Airport Hansol, Ahmedabad - IITM", "live": true}, {"id": "site_5449", "name": "Sardar Vallabhbhai Patel Stadium, Ahmedabad - IITM", "live": true}]}, {"cityName": "Agra", "stationsInCity": [{"id": "site_5464", "name": "Manoharpur, Agra - UPPCB", "live": true}, {"id": "site_5482", "name": "Rohta, Agra - UPPCB", "live": true}, {"id": "site_307", "name": "Sanjay Palace, Agra - UPPCB", "live": true}, {"id": "site_5465", "name": "Sector-3B Avas Vikas Colony, Agra - UPPCB", "live": true}, {"id": "site_5501", "name": "Shahjahan Garden, Agra - UPPCB", "live": true}, {"id": "site_5463", "name": "Shastripuram, Agra - UPPCB", "live": true}]}, {"cityName": "Delhi", "stationsInCity": [{"id": "site_5024", "name": "Alipur, Delhi - DPCC", "live": true}, {"id": "site_301", "name": "Anand Vihar, Delhi - DPCC", "live": true}, {"id": "site_1420", "name": "Ashok Vihar, Delhi - DPCC", "live": true}, {"id": "site_108", "name": "Aya Nagar, Delhi - IMD", "live": true}, {"id": "site_1560", "name": "Bawana, Delhi - DPCC", "live": true}, {"id": "site_104", "name": "Burari Crossing, Delhi - IMD", "live": true}, {"id": "site_103", "name": "CRRI Mathura Road, Delhi - IMD", "live": true}, {"id": "site_5393", "name": "Chandni Chowk, Delhi - IITM", "live": true}, {"id": "site_118", "name": "DTU, Delhi - CPCB", "live": true}, {"id": "site_1421", "name": "Dr. Karni Singh Shooting Range, Delhi - DPCC", "live": true}, {"id": "site_1422", "name": "Dwarka-Sector 8, Delhi - DPCC ", "live": true}, {"id": "site_116", "name": "East Arjun Nagar, Delhi - CPCB", "live": true}, {"id": "site_106", "name": "IGI Airport (T3), Delhi - IMD", "live": true}, {"id": "site_114", "name": "IHBAS, Dilshad Garden, Delhi - CPCB", "live": true}, {"id": "site_117", "name": "ITO, Delhi - CPCB", "live": true}, {"id": "site_1423", "name": "Jahangirpuri, Delhi - DPCC", "live": true}, {"id": "site_1424", "name": "Jawaharlal Nehru Stadium, Delhi - DPCC", "live": true}, {"id": "site_5395", "name": "Lodhi Road, Delhi - IITM", "live": true}, {"id": "site_109", "name": "Lodhi Road, Delhi - IMD", "live": true}, {"id": "site_1425", "name": "Major Dhyan Chand National Stadium, Delhi - DPCC", "live": true}, {"id": "site_122", "name": "Mandir Marg, Delhi - DPCC", "live": true}, {"id": "site_1561", "name": "Mundka, Delhi - DPCC", "live": true}, {"id": "site_115", "name": "NSIT Dwarka, Delhi - CPCB", "live": true}, {"id": "site_1427", "name": "Najafgarh, Delhi - DPCC", "live": true}, {"id": "site_1426", "name": "Narela, Delhi - DPCC", "live": true}, {"id": "site_1429", "name": "Nehru Nagar, Delhi - DPCC", "live": true}, {"id": "site_105", "name": "North Campus, DU, Delhi - IMD", "live": true}, {"id": "site_1428", "name": "Okhla Phase-2, Delhi - DPCC", "live": true}, {"id": "site_1431", "name": "Patparganj, Delhi - DPCC", "live": true}, {"id": "site_125", "name": "Punjabi Bagh, Delhi - DPCC", "live": true}, {"id": "site_1563", "name": "Pusa, Delhi - DPCC", "live": true}, {"id": "site_107", "name": "Pusa, Delhi - IMD", "live": true}, {"id": "site_124", "name": "R K Puram, Delhi - DPCC", "live": true}, {"id": "site_1430", "name": "Rohini, Delhi - DPCC", "live": true}, {"id": "site_113", "name": "Shadipur, Delhi - CPCB", "live": true}, {"id": "site_119", "name": "Sirifort, Delhi - CPCB", "live": true}, {"id": "site_1432", "name": "Sonia Vihar, Delhi - DPCC", "live": true}, {"id": "site_1562", "name": "Sri Aurobindo Marg, Delhi - DPCC", "live": true}, {"id": "site_1435", "name": "Vivek Vihar, Delhi - DPCC", "live": true}, {"id": "site_1434", "name": "Wazirpur, Delhi - DPCC", "live": true}]}, {"cityName": "Thoothukudi", "stationsInCity": [{"id": "site_5367", "name": "Meelavittan, Thoothukudi - TNPCB", "live": true}]}, {"cityName": "Gummidipoondi", "stationsInCity": [{"id": "site_5362", "name": "Anthoni Pillai Nagar, Gummidipoondi - TNPCB", "live": true}]}, {"cityName": "Mumbai", "stationsInCity": [{"id": "site_5392", "name": "Bandra Kurla Complex, Mumbai - IITM", "live": true}, {"id": "site_168", "name": "Bandra, Mumbai - MPCB", "live": true}, {"id": "site_5400", "name": "Borivali East, Mumbai - IITM", "live": true}, {"id": "site_5113", "name": "Borivali East, Mumbai - MPCB", "live": true}, {"id": "site_5399", "name": "Chakala-Andheri East, Mumbai - IITM", "live": true}, {"id": "site_5107", "name": "Chhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB", "live": true}, {"id": "site_5120", "name": "Colaba, Mumbai - MPCB", "live": true}, {"id": "site_5396", "name": "Deonar, Mumbai - IITM", "live": true}, {"id": "site_5412", "name": "Kandivali East, Mumbai - MPCB", "live": true}, {"id": "site_5397", "name": "Khindipada-Bhandup West, Mumbai - IITM", "live": true}, {"id": "site_5104", "name": "Kurla, Mumbai - MPCB", "live": true}, {"id": "site_5402", "name": "Malad West, Mumbai - IITM", "live": true}, {"id": "site_5394", "name": "Mazgaon, Mumbai - IITM", "live": true}, {"id": "site_5413", "name": "Mulund West, Mumbai - MPCB", "live": true}, {"id": "site_5398", "name": "Navy Nagar-Colaba, Mumbai - IITM", "live": true}, {"id": "site_5112", "name": "Powai, Mumbai - MPCB", "live": true}, {"id": "site_5403", "name": "Siddharth Nagar-Worli, Mumbai - IITM", "live": true}, {"id": "site_5119", "name": "Sion, Mumbai - MPCB", "live": true}, {"id": "site_5102", "name": "Vasai West, Mumbai - MPCB", "live": true}, {"id": "site_5106", "name": "Vile Parle West, Mumbai - MPCB", "live": true}, {"id": "site_5115", "name": "Worli, Mumbai - MPCB", "live": true}]}, {"cityName": "Bidar", "stationsInCity": [{"id": "site_5418", "name": "Naubad, Bidar - KSPCB", "live": true}]}, {"cityName": "Haveri", "stationsInCity": [{"id": "site_5420", "name": "Ashwini Nagar, Haveri - KSPCB", "live": true}]}, {"cityName": "Pune", "stationsInCity": [{"id": "site_5405", "name": "Alandi, Pune - IITM", "live": true}, {"id": "site_5406", "name": "Bhosari, Pune - IITM", "live": true}, {"id": "site_5407", "name": "Hadapsar, Pune - IITM", "live": true}, {"id": "site_292", "name": "Karve Road, Pune - MPCB", "live": true}, {"id": "site_5410", "name": "MIT-Kothrud, Pune - IITM", "live": true}, {"id": "site_5404", "name": "Mhada Colony, Pune - IITM", "live": true}, {"id": "site_5409", "name": "Revenue Colony-Shivajinagar, Pune - IITM", "live": true}, {"id": "site_5408", "name": "Transport Nagar-Nigdi, Pune - IITM", "live": true}]}, {"cityName": "Noida", "stationsInCity": [{"id": "site_153", "name": "Sector - 125, Noida - UPPCB", "live": true}, {"id": "site_111", "name": "Sector - 62, Noida - IMD", "live": true}, {"id": "site_5123", "name": "Sector-1, Noida - UPPCB", "live": true}, {"id": "site_5122", "name": "Sector-116, Noida - UPPCB", "live": true}]}, {"cityName": "Bahadurgarh", "stationsInCity": [{"id": "site_5045", "name": "Arya Nagar, Bahadurgarh - HSPCB", "live": true}]}, {"cityName": "Varanasi", "stationsInCity": [{"id": "site_273", "name": "Ardhali Bazar, Varanasi - UPPCB", "live": true}, {"id": "site_5469", "name": "Bhelupur, Varanasi - UPPCB", "live": true}, {"id": "site_5468", "name": "IESD Banaras Hindu University, Varanasi - UPPCB", "live": true}, {"id": "site_5475", "name": "Maldahiya, Varanasi - UPPCB", "live": true}]}, {"cityName": "Tirupati", "stationsInCity": [{"id": "site_258", "name": "Tirumala, Tirupati - APPCB", "live": true}, {"id": "site_5666", "name": "Vaikuntapuram, Tirupati - APPCB", "live": true}]}, {"cityName": "Howrah", "stationsInCity": [{"id": "site_5101", "name": "Belur Math, Howrah - WBPCB", "live": true}, {"id": "site_274", "name": "Ghusuri, Howrah - WBPCB", "live": true}, {"id": "site_1416", "name": "Padmapukur, Howrah - WBPCB", "live": true}]}, {"cityName": "Ambala", "stationsInCity": [{"id": "site_5052", "name": "Patti Mehar, Ambala - HSPCB", "live": true}]}, {"cityName": "Kolkata", "stationsInCity": [{"id": "site_5238", "name": "Ballygunge, Kolkata - WBPCB", "live": true}, {"id": "site_5129", "name": "Bidhannagar, Kolkata - WBPCB", "live": true}, {"id": "site_5110", "name": "Fort William, Kolkata - WBPCB", "live": true}, {"id": "site_5111", "name": "Jadavpur, Kolkata - WBPCB", "live": true}, {"id": "site_296", "name": "Rabindra Bharati University, Kolkata - WBPCB", "live": true}, {"id": "site_5126", "name": "Rabindra Sarobar, Kolkata - WBPCB", "live": true}, {"id": "site_309", "name": "Victoria, Kolkata - WBPCB", "live": true}]}, {"cityName": "Muzaffarnagar", "stationsInCity": [{"id": "site_1550", "name": "New Mandi, Muzaffarnagar - UPPCB", "live": true}]}, {"cityName": "Gangtok", "stationsInCity": [{"id": "site_5590", "name": "Zero Point GICI, Gangtok - SSPCB", "live": true}]}, {"cityName": "Navi Mumbai", "stationsInCity": [{"id": "site_261", "name": "Airoli, Navi Mumbai - MPCB", "live": true}, {"id": "site_5114", "name": "Mahape, Navi Mumbai - MPCB", "live": true}, {"id": "site_5103", "name": "Nerul, Navi Mumbai - MPCB", "live": true}, {"id": "site_5401", "name": "Sector-19A Nerul, Navi Mumbai - IITM", "live": true}]}, {"cityName": "Arrah", "stationsInCity": [{"id": "site_5538", "name": "New DM Office, Arrah - BSPCB", "live": true}]}, {"cityName": "Chandigarh", "stationsInCity": [{"id": "site_5491", "name": "Sector 22, Chandigarh - CPCC", "live": true}, {"id": "site_5127", "name": "Sector-25, Chandigarh - CPCC", "live": true}, {"id": "site_5582", "name": "Sector-53, Chandigarh - CPCC", "live": true}]}, {"cityName": "Chhapra", "stationsInCity": [{"id": "site_5545", "name": "Darshan Nagar, Chhapra - BSPCB", "live": true}]}, {"cityName": "Patna", "stationsInCity": [{"id": "site_5336", "name": "DRM Office Danapur, Patna - BSPCB", "live": true}, {"id": "site_5335", "name": "Govt. High School Shikarpur, Patna - BSPCB", "live": true}, {"id": "site_157", "name": "IGSC Planetarium Complex, Patna - BSPCB", "live": true}, {"id": "site_5261", "name": "Muradpur, Patna - BSPCB", "live": true}, {"id": "site_5262", "name": "Rajbansi Nagar, Patna - BSPCB", "live": true}, {"id": "site_5263", "name": "Samanpura, Patna - BSPCB", "live": true}]}, {"cityName": "Samastipur", "stationsInCity": [{"id": "site_5552", "name": "DM Office_Kasipur, Samastipur - BSPCB", "live": true}]}, {"cityName": "Jhansi", "stationsInCity": [{"id": "site_5583", "name": "Shivaji Nagar, Jhansi - UPPCB", "live": true}]}, {"cityName": "Hyderabad", "stationsInCity": [{"id": "site_199", "name": "Bollaram Industrial Area, Hyderabad - TSPCB", "live": true}, {"id": "site_262", "name": "Central University, Hyderabad - TSPCB", "live": true}, {"id": "site_5596", "name": "ECIL Kapra, Hyderabad - TSPCB", "live": true}, {"id": "site_251", "name": "ICRISAT Patancheru, Hyderabad - TSPCB", "live": true}, {"id": "site_275", "name": "IDA Pashamylaram, Hyderabad - TSPCB", "live": true}, {"id": "site_5597", "name": "IITH Kandi, Hyderabad - TSPCB", "live": true}, {"id": "site_5604", "name": "Kokapet, Hyderabad - TSPCB", "live": true}, {"id": "site_5599", "name": "Kompally Municipal Office, Hyderabad - TSPCB", "live": true}, {"id": "site_5600", "name": "Nacharam_TSIIC IALA, Hyderabad - TSPCB", "live": true}, {"id": "site_5595", "name": "New Malakpet, Hyderabad - TSPCB", "live": true}, {"id": "site_5602", "name": "Ramachandrapuram, Hyderabad - TSPCB", "live": true}, {"id": "site_294", "name": "Sanathnagar, Hyderabad - TSPCB", "live": true}, {"id": "site_5598", "name": "Somajiguda, Hyderabad - TSPCB", "live": true}, {"id": "site_298", "name": "Zoo Park, Hyderabad - TSPCB", "live": true}]}, {"cityName": "Vapi", "stationsInCity": [{"id": "site_5071", "name": "Phase-1 GIDC, Vapi - GPCB", "live": true}]}, {"cityName": "Khurja", "stationsInCity": [{"id": "site_5603", "name": "Kalindi Kunj, Khurja - UPPCB", "live": true}]}, {"cityName": "Jaipur", "stationsInCity": [{"id": "site_1393", "name": "Adarsh Nagar, Jaipur - RSPCB", "live": true}, {"id": "site_5725", "name": "Mansarovar Sector-12, Jaipur - RSPCB", "live": true}, {"id": "site_134", "name": "Police Commissionerate, Jaipur - RSPCB", "live": true}, {"id": "site_5727", "name": "Sector-2 Murlipura, Jaipur - RSPCB", "live": true}, {"id": "site_1396", "name": "Shastri Nagar, Jaipur - RSPCB", "live": true}]}, {"cityName": "Dewas", "stationsInCity": [{"id": "site_1404", "name": "Bhopal Chauraha, Dewas - MPPCB", "live": true}]}, {"cityName": "Bhopal", "stationsInCity": [{"id": "site_5708", "name": "Idgah Hills, Bhopal - MPPCB", "live": true}, {"id": "site_5650", "name": "Paryavaran Parisar, Bhopal - MPPCB", "live": true}, {"id": "site_5247", "name": "T T Nagar, Bhopal - MPPCB", "live": true}]}, {"cityName": "Hisar", "stationsInCity": [{"id": "site_5057", "name": "Urban Estate-II, Hisar - HSPCB", "live": true}]}, {"cityName": "Damoh", "stationsInCity": [{"id": "site_5040", "name": "Shrivastav Colony, Damoh - MPPCB", "live": true}]}, {"cityName": "Nashik", "stationsInCity": [{"id": "site_304", "name": "Gangapur Road, Nashik - MPCB", "live": true}]}, {"cityName": "Shivamogga", "stationsInCity": [{"id": "site_5266", "name": "Vinoba Nagara, Shivamogga - KSPCB", "live": true}]}, {"cityName": "Ludhiana", "stationsInCity": [{"id": "site_253", "name": "Punjab Agricultural University, Ludhiana - PPCB", "live": true}]}, {"cityName": "Thiruvananthapuram", "stationsInCity": [{"id": "site_5331", "name": "Kariavattom, Thiruvananthapuram - Kerala PCB", "live": true}, {"id": "site_252", "name": "Plammoodu, Thiruvananthapuram - Kerala PCB", "live": true}]}, {"cityName": "Belgaum", "stationsInCity": [{"id": "site_5432", "name": "Ramteerth Nagar, Belgaum - KSPCB", "live": true}]}, {"cityName": "Bhilai", "stationsInCity": [{"id": "site_5660", "name": "32Bungalows, Bhilai - CECB", "live": true}, {"id": "site_5536", "name": "Civic Center, Bhilai - Bhilai Steel Plant", "live": true}, {"id": "site_5659", "name": "Hathkhoj, Bhilai - CECB", "live": true}]}, {"cityName": "Raipur", "stationsInCity": [{"id": "site_5652", "name": "AIIMS, Raipur - CECB", "live": true}, {"id": "site_5655", "name": "Bhatagaon New ISBT, Raipur - CECB", "live": true}, {"id": "site_5654", "name": "Krishak Nagar, Raipur - CECB", "live": true}, {"id": "site_5653", "name": "Siltara Phase-II, Raipur - CECB", "live": true}]}, {"cityName": "Begusarai", "stationsInCity": [{"id": "site_5540", "name": "DRCC Anandpur, Begusarai - BSPCB", "live": true}]}, {"cityName": "Hubballi", "stationsInCity": [{"id": "site_1447", "name": "Deshpande Nagar, Hubballi - KSPCB", "live": true}, {"id": "site_5680", "name": "Lingaraj Nagar, Hubballi - KSPCB", "live": true}]}, {"cityName": "Dindigul", "stationsInCity": [{"id": "site_5608", "name": "Mendonsa Colony, Dindigul - TNPCB", "live": true}]}, {"cityName": "Salem", "stationsInCity": [{"id": "site_5622", "name": "Sona College of Technology, Salem - TNPCB", "live": true}]}, {"cityName": "Vellore", "stationsInCity": [{"id": "site_5615", "name": "Vasanthapuram, Vellore - TNPCB", "live": true}]}, {"cityName": "Chittoor", "stationsInCity": [{"id": "site_5665", "name": "Gangineni Cheruvu, Chittoor - APPCB", "live": true}]}, {"cityName": "Rairangpur", "stationsInCity": [{"id": "site_5672", "name": "Divisional Forest Office, Rairangpur - OSPCB", "live": true}]}, {"cityName": "Lucknow", "stationsInCity": [{"id": "site_5460", "name": "B R Ambedkar University, Lucknow - UPPCB", "live": true}, {"id": "site_5128", "name": "Gomti Nagar, Lucknow - UPPCB", "live": true}, {"id": "site_272", "name": "Kendriya Vidyalaya, Lucknow - CPCB", "live": true}, {"id": "site_5462", "name": "Kukrail Picnic Spot-1, Lucknow - UPPCB", "live": true}, {"id": "site_277", "name": "Lalbagh, Lucknow - CPCB", "live": true}, {"id": "site_1405", "name": "Nishant Ganj, Lucknow - UPPCB", "live": true}, {"id": "site_297", "name": "Talkatora District Industries Center, Lucknow - CPCB", "live": true}]}, {"cityName": "Visakhapatnam", "stationsInCity": [{"id": "site_260", "name": "GVM Corporation, Visakhapatnam - APPCB", "live": true}]}, {"cityName": "Bhiwadi", "stationsInCity": [{"id": "site_1391", "name": "RIICO Ind. Area III, Bhiwadi - RSPCB", "live": true}]}, {"cityName": "Tensa", "stationsInCity": [{"id": "site_5677", "name": "Barsua Iron Ore Mines, Tensa - OSPCB", "live": true}]}, {"cityName": "Silchar", "stationsInCity": [{"id": "site_5684", "name": "Tarapur, Silchar - PCBA", "live": true}]}, {"cityName": "Chhal", "stationsInCity": [{"id": "site_5689", "name": "Nawapara SECL Colony, Chhal - CECB", "live": true}]}, {"cityName": "Milupara", "stationsInCity": [{"id": "site_5691", "name": "Govt. Higher Secondary School, Milupara - CECB", "live": true}]}, {"cityName": "Bikaner", "stationsInCity": [{"id": "site_5696", "name": "MM Ground, Bikaner - RSPCB", "live": true}]}, {"cityName": "Kashipur", "stationsInCity": [{"id": "site_5704", "name": "Govt. Girls Inter College, Kashipur - UKPCB", "live": true}]}, {"cityName": "Indore", "stationsInCity": [{"id": "site_5248", "name": "Chhoti Gwaltoli, Indore - MPPCB", "live": true}, {"id": "site_5709", "name": "Vijay Nagar Scheme-78, Indore - Glenmark", "live": true}]}, {"cityName": "Banswara", "stationsInCity": [{"id": "site_5711", "name": "Rati Talai, Banswara - RSPCB", "live": true}]}, {"cityName": "Sawai Madhopur", "stationsInCity": [{"id": "site_5716", "name": "Sahu Nagar, Sawai Madhopur - RSPCB", "live": true}]}, {"cityName": "Karauli", "stationsInCity": [{"id": "site_5723", "name": "Satyawati Vihar, Karauli - RSPCB", "live": true}]}, {"cityName": "Sivasagar", "stationsInCity": [{"id": "site_5658", "name": "Girls College, Sivasagar - PCBA", "live": true}]}, {"cityName": "Greater Noida", "stationsInCity": [{"id": "site_1541", "name": "Knowledge Park - III, Greater Noida - UPPCB", "live": true}, {"id": "site_5121", "name": "Knowledge Park - V, Greater Noida - UPPCB", "live": true}]}, {"cityName": "Dharuhera", "stationsInCity": [{"id": "site_5044", "name": "Municipal Corporation Office, Dharuhera -  HSPCB", "live": true}]}, {"cityName": "Gurugram", "stationsInCity": [{"id": "site_5025", "name": "NISE Gwal Pahari, Gurugram - IMD", "live": true}, {"id": "site_5345", "name": "Sector-51, Gurugram - HSPCB", "live": true}, {"id": "site_5344", "name": "Teri Gram, Gurugram - HSPCB", "live": true}, {"id": "site_146", "name": "Vikas Sadan, Gurugram - HSPCB", "live": true}]}, {"cityName": "Kanpur", "stationsInCity": [{"id": "site_5500", "name": "FTI Kidwai Nagar, Kanpur - UPPCB", "live": true}, {"id": "site_5416", "name": "IITK, Kanpur - IITK", "live": true}, {"id": "site_5474", "name": "NSI Kalyanpur, Kanpur - UPPCB", "live": true}, {"id": "site_276", "name": "Nehru Nagar, Kanpur - UPPCB", "live": true}]}, {"cityName": "Moradabad", "stationsInCity": [{"id": "site_5554", "name": "Buddhi Vihar, Moradabad - UPPCB", "live": true}, {"id": "site_5556", "name": "Eco Herbal Park, Moradabad - UPPCB", "live": true}, {"id": "site_5537", "name": "Employment Office, Moradabad - UPPCB", "live": true}, {"id": "site_5555", "name": "Jigar Colony, Moradabad - UPPCB", "live": true}, {"id": "site_5620", "name": "Kashiram Nagar, Moradabad - UPPCB", "live": true}, {"id": "site_1398", "name": "Lajpat Nagar, Moradabad - UPPCB", "live": true}, {"id": "site_5613", "name": "Transport Nagar, Moradabad - UPPCB", "live": true}]}, {"cityName": "Chennai", "stationsInCity": [{"id": "site_293", "name": "Alandur Bus Depot, Chennai - CPCB", "live": true}, {"id": "site_5361", "name": "Arumbakkam, Chennai - TNPCB", "live": true}, {"id": "site_5618", "name": "Gandhi Nagar_Ennore, Chennai - TNPCB", "live": true}, {"id": "site_5365", "name": "Kodungaiyur, Chennai - TNPCB", "live": true}, {"id": "site_5092", "name": "Manali Village, Chennai - TNPCB", "live": true}, {"id": "site_306", "name": "Manali, Chennai - CPCB", "live": true}, {"id": "site_5363", "name": "Perungudi, Chennai - TNPCB", "live": true}, {"id": "site_5364", "name": "Royapuram, Chennai - TNPCB", "live": true}, {"id": "site_288", "name": "Velachery Res. Area, Chennai - CPCB", "live": true}]}, {"cityName": "Bulandshahr", "stationsInCity": [{"id": "site_1542", "name": "Yamunapuram, Bulandshahr - UPPCB", "live": true}]}, {"cityName": "Nagpur", "stationsInCity": [{"id": "site_303", "name": "Opp GPO Civil Lines, Nagpur - MPCB", "live": true}]}, {"cityName": "Muzaffarpur", "stationsInCity": [{"id": "site_5370", "name": "Buddha Colony, Muzaffarpur - BSPCB", "live": true}, {"id": "site_5479", "name": "MIT-Daudpur Kothi, Muzaffarpur - BSPCB", "live": true}, {"id": "site_158", "name": "Muzaffarpur Collectorate, Muzaffarpur - BSPCB", "live": true}]}, {"cityName": "Aurangabad", "stationsInCity": [{"id": "site_5544", "name": "Gurdeo Nagar, Aurangabad - BSPCB", "live": true}, {"id": "site_198", "name": "More Chowk Waluj, Aurangabad - MPCB", "live": true}]}, {"cityName": "Bihar Sharif", "stationsInCity": [{"id": "site_5481", "name": "D M Colony, Bihar Sharif - BSPCB", "live": true}]}, {"cityName": "Purnia", "stationsInCity": [{"id": "site_5549", "name": "Mariam Nagar, Purnia - BSPCB", "live": true}]}, {"cityName": "Saharsa", "stationsInCity": [{"id": "site_5551", "name": "Police Line, Saharsa - BSPCB", "live": true}]}, {"cityName": "Palkalaiperur", "stationsInCity": [{"id": "site_5626", "name": "Bharathidasan University, Palkalaiperur - TNPCB", "live": true}]}, {"cityName": "Meerut", "stationsInCity": [{"id": "site_5258", "name": "Ganga Nagar, Meerut - UPPCB", "live": true}, {"id": "site_5109", "name": "Jai Bhim Nagar, Meerut - UPPCB", "live": true}, {"id": "site_5257", "name": "Pallavpuram Phase 2, Meerut - UPPCB", "live": true}]}, {"cityName": "Jind", "stationsInCity": [{"id": "site_5056", "name": "Police Lines, Jind - HSPCB", "live": true}]}, {"cityName": "Sirsa", "stationsInCity": [{"id": "site_5051", "name": "F-Block, Sirsa - HSPCB", "live": true}]}, {"cityName": "Faridabad", "stationsInCity": [{"id": "site_5340", "name": "New Industrial Town, Faridabad - HSPCB", "live": true}, {"id": "site_5342", "name": "Sector 11, Faridabad - HSPCB", "live": true}, {"id": "site_5341", "name": "Sector 30, Faridabad - HSPCB", "live": true}, {"id": "site_263", "name": "Sector- 16A, Faridabad - HSPCB", "live": true}]}, {"cityName": "Maihar", "stationsInCity": [{"id": "site_5068", "name": "Sahilara, Maihar - KJS Cements", "live": true}]}, {"cityName": "Hassan", "stationsInCity": [{"id": "site_5448", "name": "B.Katihalli, Hassan - KSPCB", "live": true}]}, {"cityName": "Srinagar", "stationsInCity": [{"id": "site_5424", "name": "Rajbagh, Srinagar - JKSPCB", "live": true}]}, {"cityName": "Dehradun", "stationsInCity": [{"id": "site_5594", "name": "Doon University, Dehradun - UKPCB", "live": true}]}, {"cityName": "Agartala", "stationsInCity": [{"id": "site_5587", "name": "Bardowali, Agartala - Tripura SPCB", "live": true}, {"id": "site_5377", "name": "Kunjaban, Agartala - Tripura SPCB", "live": true}]}, {"cityName": "Karnal", "stationsInCity": [{"id": "site_5049", "name": "Sector-12, Karnal - HSPCB", "live": true}]}, {"cityName": "Brajrajnagar", "stationsInCity": [{"id": "site_1410", "name": "GM Office, Brajrajnagar - OSPCB", "live": true}]}, {"cityName": "Chikkamagaluru", "stationsInCity": [{"id": "site_5265", "name": "Kalyana Nagara, Chikkamagaluru - KSPCB", "live": true}]}, {"cityName": "Pali", "stationsInCity": [{"id": "site_1395", "name": "Indira Colony Vistar, Pali - RSPCB", "live": true}]}, {"cityName": "Alwar", "stationsInCity": [{"id": "site_1390", "name": "Moti Doongri, Alwar - RSPCB", "live": true}]}, {"cityName": "Vijayawada", "stationsInCity": [{"id": "site_5685", "name": "Kanuru, Vijayawada - APPCB", "live": true}, {"id": "site_257", "name": "PWD Grounds, Vijayawada - APPCB", "live": true}]}, {"cityName": "Ernakulam", "stationsInCity": [{"id": "site_5272", "name": "Kacheripady, Ernakulam - Kerala PCB", "live": true}]}, {"cityName": "Coimbatore", "stationsInCity": [{"id": "site_5623", "name": "PSG College of Arts and Science, Coimbatore - TNPCB", "live": true}, {"id": "site_5094", "name": "SIDCO Kurichi, Coimbatore - TNPCB", "live": true}]}, {"cityName": "Mandideep", "stationsInCity": [{"id": "site_1403", "name": "Sector-D Industrial Area, Mandideep - MPPCB", "live": true}]}, {"cityName": "Talcher", "stationsInCity": [{"id": "site_1408", "name": "Talcher Coalfields,Talcher - OSPCB", "live": true}]}, {"cityName": "Guwahati", "stationsInCity": [{"id": "site_5651", "name": "IITG, Guwahati - PCBA", "live": true}, {"id": "site_5683", "name": "LGBI Airport, Guwahati - PCBA", "live": true}, {"id": "site_5417", "name": "Pan Bazaar, Guwahati - PCBA", "live": true}, {"id": "site_5073", "name": "Railway Colony, Guwahati - PCBA", "live": true}]}, {"cityName": "Korba", "stationsInCity": [{"id": "site_5656", "name": "Rampur, Korba - CECB", "live": true}, {"id": "site_5657", "name": "Urja Nagar, Korba - CECB", "live": true}]}, {"cityName": "Cuddalore", "stationsInCity": [{"id": "site_5621", "name": "Kudikadu, Cuddalore - TNPCB", "live": true}, {"id": "site_5611", "name": "Semmandalam, Cuddalore - TNPCB", "live": true}]}, {"cityName": "Surat", "stationsInCity": [{"id": "site_5664", "name": "Science Center, Surat - SMC", "live": true}]}, {"cityName": "Kanchipuram", "stationsInCity": [{"id": "site_5619", "name": "Kilambi, Kanchipuram - TNPCB", "live": true}]}, {"cityName": "Tirupur", "stationsInCity": [{"id": "site_5607", "name": "Kumaran College, Tirupur - TNPCB", "live": true}]}, {"cityName": "Dharwad", "stationsInCity": [{"id": "site_5638", "name": "Kalabhavan, Dharwad - KSPCB", "live": true}]}, {"cityName": "Keonjhar", "stationsInCity": [{"id": "site_5671", "name": "Jagamohanpur, Keonjhar - OSPCB", "live": true}]}, {"cityName": "Suakati", "stationsInCity": [{"id": "site_5676", "name": "OMC Colony, Suakati - OSPCB", "live": true}]}, {"cityName": "Chandrapur", "stationsInCity": [{"id": "site_271", "name": "Chauhan Colony, Chandrapur - MPCB", "live": true}, {"id": "site_295", "name": "MIDC Khutala, Chandrapur - MPCB", "live": true}]}, {"cityName": "Byrnihat", "stationsInCity": [{"id": "site_5669", "name": "Central Academy for SFS, Byrnihat - PCBA", "live": true}]}, {"cityName": "Rourkela", "stationsInCity": [{"id": "site_5687", "name": "Fertilizer Township, Rourkela - OSPCB", "live": true}, {"id": "site_5675", "name": "Raghunathpali, Rourkela - OSPCB", "live": true}, {"id": "site_5688", "name": "Sector-2, Rourkela - OSPCB", "live": true}]}, {"cityName": "Kunjemura", "stationsInCity": [{"id": "site_5690", "name": "OP Jindal School, Kunjemura - CECB", "live": true}]}, {"cityName": "Bharatpur", "stationsInCity": [{"id": "site_5695", "name": "Krishna Nagar, Bharatpur - RSPCB", "live": true}]}, {"cityName": "Rishikesh", "stationsInCity": [{"id": "site_5703", "name": "Shivaji Nagar, Rishikesh - UKPCB", "live": true}]}, {"cityName": "Dhanbad", "stationsInCity": [{"id": "site_5710", "name": "Sardar Patel Nagar, Dhanbad - JSPCB", "live": true}]}, {"cityName": "Hanumangarh", "stationsInCity": [{"id": "site_5715", "name": "Housing Board, Hanumangarh - RSPCB", "live": true}]}, {"cityName": "Sikar", "stationsInCity": [{"id": "site_5722", "name": "Radhakishan Pura, Sikar - RSPCB", "live": true}]}, {"cityName": "Palwal ", "stationsInCity": [{"id": "site_5050", "name": "Shyam Nagar, Palwal - HSPCB", "live": true}]}, {"cityName": "Pithampur", "stationsInCity": [{"id": "site_1402", "name": "Sector-2 Industrial Area, Pithampur - MPPCB", "live": true}]}, {"cityName": "Solapur", "stationsInCity": [{"id": "site_302", "name": "Solapur, Solapur - MPCB", "live": true}]}, {"cityName": "Siliguri", "stationsInCity": [{"id": "site_1419", "name": "Ward-32 Bapupara, Siliguri - WBPCB", "live": true}]}, {"cityName": "Sasaram", "stationsInCity": [{"id": "site_5485", "name": "Dada Peer, Sasaram - BSPCB", "live": true}]}, {"cityName": "Motihari", "stationsInCity": [{"id": "site_5478", "name": "Gandak Colony, Motihari - BSPCB", "live": true}]}, {"cityName": "Gaya", "stationsInCity": [{"id": "site_159", "name": "Collectorate, Gaya - BSPCB", "live": true}, {"id": "site_5548", "name": "Kareemganj, Gaya - BSPCB", "live": true}, {"id": "site_5338", "name": "SFTI Kusdihra, Gaya - BSPCB", "live": true}]}, {"cityName": "Bhagalpur", "stationsInCity": [{"id": "site_5543", "name": "DM Office_Kachari Chowk, Bhagalpur - BSPCB", "live": true}, {"id": "site_5541", "name": "Mayaganj, Bhagalpur - BSPCB", "live": true}]}, {"cityName": "Baddi", "stationsInCity": [{"id": "site_5586", "name": "HIMUDA Complex Phase-1, Baddi - HPPCB", "live": true}]}, {"cityName": "Shillong", "stationsInCity": [{"id": "site_5593", "name": "JN Stadium, Shillong - Meghalaya PCB", "live": true}, {"id": "site_5131", "name": "Lumpyngngad, Shillong - Meghalaya PCB", "live": true}]}, {"cityName": "Ariyalur", "stationsInCity": [{"id": "site_5606", "name": "Keelapalur, Ariyalur - TNPCB", "live": true}]}, {"cityName": "Kalaburagi", "stationsInCity": [{"id": "site_1565", "name": "Lal Bahadur Shastri Nagar, Kalaburagi - KSPCB", "live": true}, {"id": "site_5679", "name": "Mahatma Basaveswar Colony, Kalaburgi - KSPCB", "live": true}]}, {"cityName": "Prayagraj", "stationsInCity": [{"id": "site_5461", "name": "Jhunsi, Prayagraj - UPPCB", "live": true}, {"id": "site_5459", "name": "Motilal Nehru NIT, Prayagraj - UPPCB", "live": true}, {"id": "site_5484", "name": "Nagar Nigam, Prayagraj - UPPCB", "live": true}]}, {"cityName": "Madikeri", "stationsInCity": [{"id": "site_5391", "name": "Stuart Hill, Madikeri - KSPCB", "live": true}]}, {"cityName": "Firozabad", "stationsInCity": [{"id": "site_5480", "name": "Nagla Bhau, Firozabad - UPPCB", "live": true}, {"id": "site_5584", "name": "Vibhab Nagar, Firozabad - UPPCB", "live": true}]}, {"cityName": "Kota", "stationsInCity": [{"id": "site_5707", "name": "Dhanmandi, Kota - RSPCB", "live": true}, {"id": "site_5701", "name": "Nayapura, Kota - RSPCB", "live": true}, {"id": "site_1394", "name": "Shrinath Puram, Kota - RSPCB", "live": true}]}, {"cityName": "Kollam", "stationsInCity": [{"id": "site_5334", "name": "Polayathode, Kollam - Kerala PCB", "live": true}]}, {"cityName": "Kozhikode", "stationsInCity": [{"id": "site_5271", "name": "Palayam, Kozhikode - Kerala PCB", "live": true}]}, {"cityName": "Sagar", "stationsInCity": [{"id": "site_5662", "name": "Civil Lines, Sagar - MPPCB", "live": true}, {"id": "site_5269", "name": "Deen Dayal Nagar, Sagar - MPPCB", "live": true}]}, {"cityName": "Mandikhera", "stationsInCity": [{"id": "site_5055", "name": "General Hospital, Mandikhera - HSPCB", "live": true}]}, {"cityName": "Kalyan", "stationsInCity": [{"id": "site_5118", "name": "Khadakpada, Kalyan - MPCB", "live": true}]}, {"cityName": "Mysuru", "stationsInCity": [{"id": "site_5125", "name": "Hebbal 1st Stage, Mysuru - KSPCB", "live": true}]}, {"cityName": "Vatva", "stationsInCity": [{"id": "site_5067", "name": "Phase-4 GIDC, Vatva - GPCB", "live": true}]}, {"cityName": "Panipat", "stationsInCity": [{"id": "site_5048", "name": "Sector-18, Panipat - HSPCB", "live": true}]}, {"cityName": "Kurukshetra ", "stationsInCity": [{"id": "site_5043", "name": "Sector-7, Kurukshetra - HSPCB", "live": true}]}, {"cityName": "Puducherry", "stationsInCity": [{"id": "site_5423", "name": "Jawahar Nagar, Puducherry - PPCC", "live": true}]}, {"cityName": "Amritsar", "stationsInCity": [{"id": "site_256", "name": "Golden Temple, Amritsar - PPCB", "live": true}]}, {"cityName": "Jalandhar", "stationsInCity": [{"id": "site_1438", "name": "Civil Line, Jalandhar - PPCB", "live": true}]}, {"cityName": "Bagalkot", "stationsInCity": [{"id": "site_5264", "name": "Vidayagiri, Bagalkot - KSPCB", "live": true}]}, {"cityName": "Kannur", "stationsInCity": [{"id": "site_5276", "name": "Thavakkara, Kannur - Kerala PCB", "live": true}]}, {"cityName": "Aizawl", "stationsInCity": [{"id": "site_5346", "name": "Sikulpuikawn, Aizawl - Mizoram PCB", "live": true}]}, {"cityName": "Ramanathapuram", "stationsInCity": [{"id": "site_5625", "name": "Chalai Bazaar, Ramanathapuram - TNPCB", "live": true}]}, {"cityName": "Durgapur", "stationsInCity": [{"id": "site_299", "name": "Sidhu Kanhu Indoor Stadium, Durgapur - WBPCB", "live": true}]}, {"cityName": "Anantapur", "stationsInCity": [{"id": "site_5632", "name": "Gulzarpet, Anantapur - APPCB", "live": true}]}, {"cityName": "Bareilly", "stationsInCity": [{"id": "site_5628", "name": "Civil Lines, Bareilly - UPPCB", "live": true}, {"id": "site_5601", "name": "Rajendra Nagar, Bareilly - UPPCB", "live": true}]}, {"cityName": "Nalbari", "stationsInCity": [{"id": "site_5668", "name": "Bata Chowk, Nalbari - PCBA", "live": true}]}, {"cityName": "Baripada", "stationsInCity": [{"id": "site_5670", "name": "Meher Colony, Baripada - OSPCB", "live": true}]}, {"cityName": "Jodhpur", "stationsInCity": [{"id": "site_136", "name": "Collectorate, Jodhpur - RSPCB", "live": true}, {"id": "site_5720", "name": "Jhalamand, Jodhpur - RSPCB", "live": true}, {"id": "site_5694", "name": "Samrat Ashok Udhyan, Jodhpur - RSPCB", "live": true}]}, {"cityName": "Satna", "stationsInCity": [{"id": "site_1433", "name": "Bandhavgar Colony, Satna - Birla Cement", "live": true}]}, {"cityName": "Rajamahendravaram", "stationsInCity": [{"id": "site_1399", "name": "Anand Kala Kshetram, Rajamahendravaram - APPCB", "live": true}]}, {"cityName": "Manguraha", "stationsInCity": [{"id": "site_5550", "name": "Forest Rest House, Manguraha - BSPCB", "live": true}]}, {"cityName": "Charkhi Dadri", "stationsInCity": [{"id": "site_5339", "name": "Mini Secretariat, Charkhi Dadri - HSPCB", "live": true}]}, {"cityName": "Tumakuru", "stationsInCity": [{"id": "site_5682", "name": "Thimmalapura, Tumakuru - KSPCB", "live": true}]}, {"cityName": "Churu", "stationsInCity": [{"id": "site_5699", "name": "Subash Chowk, Churu - RSPCB", "live": true}]}, {"cityName": "Tonk", "stationsInCity": [{"id": "site_5702", "name": "Shastri Nagar, Tonk - RSPCB", "live": true}]}, {"cityName": "Barmer", "stationsInCity": [{"id": "site_5714", "name": "Railway Colony, Barmer - RSPCB", "live": true}]}, {"cityName": "Sri Ganganagar", "stationsInCity": [{"id": "site_5719", "name": "Old City, Sri Ganganagar - RSPCB", "live": true}]}, {"cityName": "Pratapgarh", "stationsInCity": [{"id": "site_5721", "name": "Pragati Nagar, Pratapgarh - RSPCB", "live": true}]}, {"cityName": "Rohtak", "stationsInCity": [{"id": "site_147", "name": "MD University, Rohtak - HSPCB", "live": true}]}, {"cityName": "Amaravati", "stationsInCity": [{"id": "site_1406", "name": "Secretariat, Amaravati - APPCB", "live": true}]}, {"cityName": "Darbhanga", "stationsInCity": [{"id": "site_5477", "name": "Town Hall - Lal Bagh, Darbhanga - BSPCB", "live": true}]}, {"cityName": "Buxar", "stationsInCity": [{"id": "site_5542", "name": "Central Jail, Buxar - BSPCB", "live": true}]}, {"cityName": "Kishanganj", "stationsInCity": [{"id": "site_5547", "name": "SDM Office_Khagra, Kishanganj - BSPCB", "live": true}]}, {"cityName": "Rajgir", "stationsInCity": [{"id": "site_5489", "name": "Dangi Tola, Rajgir - BSPCB", "live": true}]}, {"cityName": "Mandi Gobindgarh", "stationsInCity": [{"id": "site_255", "name": "RIMT University, Mandi Gobindgarh - PPCB", "live": true}]}, {"cityName": "Jabalpur", "stationsInCity": [{"id": "site_5249", "name": "Marhatal, Jabalpur - MPPCB", "live": true}]}, {"cityName": "Eloor", "stationsInCity": [{"id": "site_5105", "name": "Udyogamandal, Eloor - Kerala PCB", "live": true}]}, {"cityName": "Gandhinagar", "stationsInCity": [{"id": "site_5458", "name": "GIFT City, Gandhinagar - IITM", "live": true}, {"id": "site_5457", "name": "IIPHG Lekawada, Gandhinagar - IITM", "live": true}, {"id": "site_5066", "name": "Sector-10, Gandhinagar - GPCB", "live": true}]}, {"cityName": "Patiala", "stationsInCity": [{"id": "site_1437", "name": "Model Town, Patiala - PPCB", "live": true}]}, {"cityName": "Chamarajanagar", "stationsInCity": [{"id": "site_5124", "name": "Urban, Chamarajanagar - KSPCB", "live": true}]}, {"cityName": "Kochi", "stationsInCity": [{"id": "site_5270", "name": "Vyttila, Kochi - Kerala PCB", "live": true}]}, {"cityName": "Hapur", "stationsInCity": [{"id": "site_5023", "name": "Anand Vihar, Hapur - UPPCB", "live": true}]}, {"cityName": "Ratlam", "stationsInCity": [{"id": "site_5042", "name": "Shasthri Nagar, Ratlam - IPCA Lab", "live": true}]}, {"cityName": "Bhiwani", "stationsInCity": [{"id": "site_5047", "name": "H.B. Colony, Bhiwani - HSPCB", "live": true}]}, {"cityName": "Davanagere", "stationsInCity": [{"id": "site_5422", "name": "Devaraj Urs Badavane, Davanagere - KSPCB", "live": true}]}, {"cityName": "Koppal", "stationsInCity": [{"id": "site_5415", "name": "Diwator Nagar, Koppal - KSPCB", "live": true}]}, {"cityName": "Thrissur", "stationsInCity": [{"id": "site_5390", "name": "Corporation Ground, Thrissur - Kerala PCB", "live": true}]}, {"cityName": "Gorakhpur", "stationsInCity": [{"id": "site_5472", "name": "Madan Mohan Malaviya University of Technology, Gorakhpur - UPPCB", "live": true}]}, {"cityName": "Singrauli", "stationsInCity": [{"id": "site_1401", "name": "Suryakiran Bhawan NCL, Singrauli - MPPCB", "live": true}]}, {"cityName": "Chikkaballapur", "stationsInCity": [{"id": "site_1557", "name": "Chikkaballapur Rural, Chikkaballapur - KSPCB", "live": true}]}, {"cityName": "Rupnagar", "stationsInCity": [{"id": "site_1538", "name": "Ratanpura, Rupnagar - Ambuja Cements", "live": true}]}, {"cityName": "Naharlagun", "stationsInCity": [{"id": "site_5446", "name": "Naharlagun, Naharlagun - APSPCB", "live": true}]}, {"cityName": "Asansol", "stationsInCity": [{"id": "site_1418", "name": "Asansol Court Area, Asansol - WBPCB", "live": true}]}, {"cityName": "Imphal", "stationsInCity": [{"id": "site_5592", "name": "DM College of Science, Imphal - Manipur PCB", "live": true}, {"id": "site_5591", "name": "Manipur University, Imphal - Manipur PCB", "live": true}]}, {"cityName": "Fatehabad", "stationsInCity": [{"id": "site_5054", "name": "Huda Sector, Fatehabad - HSPCB", "live": true}]}, {"cityName": "Baghpat", "stationsInCity": [{"id": "site_1569", "name": "New Collectorate, Baghpat - UPPCB", "live": true}, {"id": "site_5585", "name": "Sardar Patel Inter College, Baghpat - UPPCB", "live": true}]}, {"cityName": "Chengalpattu", "stationsInCity": [{"id": "site_5605", "name": "Crescent University, Chengalpattu - TNPCB", "live": true}]}, {"cityName": "Ooty", "stationsInCity": [{"id": "site_5624", "name": "Bombay Castel, Ooty - TNPCB", "live": true}]}, {"cityName": "Hosur", "stationsInCity": [{"id": "site_5612", "name": "SIPCOT Phase-1, Hosur - TNPCB", "live": true}]}, {"cityName": "Nayagarh", "stationsInCity": [{"id": "site_5674", "name": "Dabuna, Nayagarh - OSPCB", "live": true}]}, {"cityName": "Panchkula", "stationsInCity": [{"id": "site_161", "name": "Sector-6, Panchkula - HSPCB ", "live": true}]}, {"cityName": "Kadapa", "stationsInCity": [{"id": "site_5693", "name": "Yerramukkapalli, Kadapa - APPCB", "live": true}]}, {"cityName": "Nagaon", "stationsInCity": [{"id": "site_5706", "name": "Christianpatty, Nagaon - PCBA", "live": true}]}, {"cityName": "Dausa", "stationsInCity": [{"id": "site_5713", "name": "Khatikan Mohalla, Dausa - RSPCB", "live": true}]}, {"cityName": "Rajsamand", "stationsInCity": [{"id": "site_5718", "name": "Dhoinda, Rajsamand - RSPCB", "live": true}]}, {"cityName": "Thane", "stationsInCity": [{"id": "site_305", "name": "Pimpleshwar Mandir, Thane - MPCB", "live": true}]}, {"cityName": "Ankleshwar", "stationsInCity": [{"id": "site_5065", "name": "GIDC, Ankleshwar - GPCB", "live": true}]}, {"cityName": "Vijayapura", "stationsInCity": [{"id": "site_5267", "name": "Ibrahimpur, Vijayapura - KSPCB", "live": true}]}, {"cityName": "Nandesari", "stationsInCity": [{"id": "site_5274", "name": "GIDC, Nandesari - Nandesari Ind. Association", "live": true}]}, {"cityName": "Ajmer", "stationsInCity": [{"id": "site_1392", "name": "Civil Lines,  Ajmer - RSPCB", "live": true}]}, {"cityName": "Udaipur", "stationsInCity": [{"id": "site_1397", "name": "Ashok Nagar, Udaipur - RSPCB", "live": true}]}, {"cityName": "Katni", "stationsInCity": [{"id": "site_5250", "name": "Gole Bazar, Katni - MPPCB", "live": true}]}, {"cityName": "Ramanagara", "stationsInCity": [{"id": "site_5255", "name": "Vijay Nagar, Ramanagara - KSPCB", "live": true}]}, {"cityName": "Kaithal", "stationsInCity": [{"id": "site_5072", "name": "Rishi Nagar, Kaithal - HSPCB", "live": true}]}, {"cityName": "Kohima", "stationsInCity": [{"id": "site_5375", "name": "PWD Juction, Kohima - NPCB", "live": true}]}, {"cityName": "Mangalore", "stationsInCity": [{"id": "site_5421", "name": "Kadri, Mangalore - KSPCB", "live": true}]}, {"cityName": "Raichur", "stationsInCity": [{"id": "site_5414", "name": "Haji Colony, Raichur - KSPCB", "live": true}]}, {"cityName": "Sonipat", "stationsInCity": [{"id": "site_5041", "name": "Murthal, Sonipat - HSPCB", "live": true}]}, {"cityName": "Udupi", "stationsInCity": [{"id": "site_5433", "name": "Brahmagiri, Udupi - KSPCB", "live": true}]}, {"cityName": "Gadag", "stationsInCity": [{"id": "site_5419", "name": "Panchal Nagar, Gadag - KSPCB", "live": true}]}, {"cityName": "Manesar", "stationsInCity": [{"id": "site_5039", "name": "Sector-2 IMT, Manesar - HSPCB", "live": true}]}, {"cityName": "Bettiah", "stationsInCity": [{"id": "site_5476", "name": "Kamalnath Nagar, Bettiah - BSPCB", "live": true}]}, {"cityName": "Vrindavan", "stationsInCity": [{"id": "site_5483", "name": "Omex Eternity, Vrindavan - UPPCB", "live": true}]}, {"cityName": "Bathinda", "stationsInCity": [{"id": "site_1549", "name": "Hardev Nagar, Bathinda - PPCB", "live": true}]}, {"cityName": "Narnaul", "stationsInCity": [{"id": "site_5053", "name": "Shastri Nagar, Narnaul - HSPCB", "live": true}]}, {"cityName": "Munger", "stationsInCity": [{"id": "site_5490", "name": "Town Hall, Munger - BSPCB", "live": true}]}, {"cityName": "Hajipur", "stationsInCity": [{"id": "site_5337", "name": "Industrial Area, Hajipur - BSPCB", "live": true}]}, {"cityName": "Ujjain", "stationsInCity": [{"id": "site_1400", "name": "Mahakaleshwar Temple, Ujjain - MPPCB", "live": true}]}, {"cityName": "Siwan", "stationsInCity": [{"id": "site_5553", "name": "Chitragupta Nagar, Siwan - BSPCB", "live": true}]}, {"cityName": "Katihar", "stationsInCity": [{"id": "site_5546", "name": "Mirchaibari, Katihar - BSPCB", "live": true}]}, {"cityName": "Khanna", "stationsInCity": [{"id": "site_1450", "name": "Kalal Majra, Khanna - PPCB", "live": true}]}, {"cityName": "Araria", "stationsInCity": [{"id": "site_5539", "name": "Kharahiya Basti, Araria - BSPCB", "live": true}]}, {"cityName": "Kolar", "stationsInCity": [{"id": "site_1551", "name": "Tamaka Ind. Area, Kolar - KSPCB", "live": true}]}, {"cityName": "Ballabgarh", "stationsInCity": [{"id": "site_5060", "name": "Nathu Colony, Ballabgarh - HSPCB", "live": true}]}, {"cityName": "Yamuna Nagar", "stationsInCity": [{"id": "site_5046", "name": "Gobind Pura, Yamuna Nagar - HSPCB", "live": true}]}, {"cityName": "Bilaspur", "stationsInCity": [{"id": "site_5503", "name": "Mangala, Bilaspur - NTPC", "live": true}]}, {"cityName": "Bileipada", "stationsInCity": [{"id": "site_5673", "name": "Tata Township, Bileipada - OSPCB", "live": true}]}, {"cityName": "Jorapokhar", "stationsInCity": [{"id": "site_254", "name": "Tata Stadium, Jorapokhar - JSPCB", "live": true}]}, {"cityName": "Tumidih", "stationsInCity": [{"id": "site_5692", "name": "OP Jindal Industrial Park, Tumidih - CECB", "live": true}]}, {"cityName": "Dholpur", "stationsInCity": [{"id": "site_5700", "name": "Raja Ganj, Dholpur - RSPCB", "live": true}]}, {"cityName": "Sirohi", "stationsInCity": [{"id": "site_5705", "name": "Vedhaynath Colony, Sirohi - RSPCB", "live": true}]}, {"cityName": "Haldia", "stationsInCity": [{"id": "site_300", "name": "Priyambada Housing Estate, Haldia - WBPCB", "live": true}]}, {"cityName": "Chittorgarh", "stationsInCity": [{"id": "site_5712", "name": "Shastri Nagar, Chittorgarh - RSPCB", "live": true}]}, {"cityName": "Jhunjhunu", "stationsInCity": [{"id": "site_5717", "name": "Indra Nagar, Jhunjhunu - RSPCB", "live": true}]}, {"cityName": "Jhalawar", "stationsInCity": [{"id": "site_5724", "name": "Rajlaxmi Nagar, Jhalawar - RSPCB", "live": true}]}], "parameters": [{"station_id": "site_1555", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5254", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5273", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5083", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5456", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5451", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5449", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5463", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5393", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5367", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5362", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5413", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5418", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5420", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5406", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_5122", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5045", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5468", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5482", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5475", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_258", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_1416", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5052", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5110", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1550", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5590", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5401", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5538", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5127", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5545", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5398", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5336", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5552", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5583", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5595", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5071", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5603", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1396", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1404", "parameters": [{"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5247", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5057", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5040", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_5115", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_304", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5266", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_253", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}]}, {"station_id": "site_5331", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5103", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5432", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5660", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5653", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5261", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_164", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5540", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_1447", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}]}, {"station_id": "site_309", "parameters": [{"id": "parameter_203", "name": "CO"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_5608", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5622", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5615", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_296", "parameters": [{"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5665", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_5672", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_1562", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_157", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_277", "parameters": [{"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_311", "name": "NH3"}]}, {"station_id": "site_1435", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1430", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1423", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_114", "parameters": [{"id": "parameter_313", "name": "CH4"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_303", "name": "NMHC"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_318", "name": "THC"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_119", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_260", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_1391", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1428", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_107", "parameters": [{"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5677", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_272", "parameters": [{"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5684", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5689", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5691", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5696", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5704", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_5709", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5711", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5716", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5723", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5658", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5121", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5044", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5025", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5474", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5501", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5397", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5537", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_288", "parameters": [{"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_1542", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_303", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5107", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_308", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}]}, {"station_id": "site_5479", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5335", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5544", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5481", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5400", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5392", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5126", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}]}, {"station_id": "site_5549", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5551", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5582", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5626", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5556", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_1554", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5082", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5258", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5056", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5051", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}]}, {"station_id": "site_5455", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5450", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5342", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5462", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5068", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5448", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5361", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5412", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5424", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5594", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5587", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5049", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5102", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_1410", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5265", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5114", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5119", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_1395", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1390", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_257", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5272", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}]}, {"station_id": "site_5094", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_1403", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_144", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}]}, {"station_id": "site_1408", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_232", "name": "Toluene"}]}, {"station_id": "site_5405", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_5417", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5657", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5652", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5621", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5664", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5619", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5607", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5638", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5599", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5602", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5671", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5676", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_118", "parameters": [{"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}]}, {"station_id": "site_295", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_113", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_125", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_303", "name": "NMHC"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_315", "name": "SPM"}, {"id": "parameter_318", "name": "THC"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_232", "name": "Toluene"}]}, {"station_id": "site_1427", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_276", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_215", "name": "PM10"}]}, {"station_id": "site_199", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_163", "parameters": [{"id": "parameter_238", "name": "BP"}, {"id": "parameter_303", "name": "NMHC"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_318", "name": "THC"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_106", "parameters": [{"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1561", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_168", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_252", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_1434", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1422", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_5683", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}]}, {"station_id": "site_5669", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}]}, {"station_id": "site_5688", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_5690", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5695", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5703", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_271", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5708", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5710", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5715", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5722", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5727", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5081", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5050", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1402", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_198", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}]}, {"station_id": "site_117", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5120", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_294", "parameters": [{"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_307", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_302", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1541", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_1558", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_1419", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5396", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5101", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5485", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_5478", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5548", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5543", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5586", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5593", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5555", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5598", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5257", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5606", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5536", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}]}, {"station_id": "site_1565", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5341", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5459", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5461", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5454", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5377", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5391", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5409", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5404", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_5365", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5416", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5480", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5500", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5113", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_1394", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5334", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5271", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5269", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}]}, {"station_id": "site_1553", "parameters": [{"id": "parameter_312", "name": "SO2"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5055", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5118", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5125", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5106", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5067", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5048", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5043", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5651", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5423", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5656", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_256", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_235", "name": "RH"}]}, {"station_id": "site_1438", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5264", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5276", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5346", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5625", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5618", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_299", "parameters": [{"id": "parameter_203", "name": "CO"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5632", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_5601", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5613", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5620", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5668", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}]}, {"station_id": "site_5670", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5675", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_275", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_162", "parameters": [{"id": "parameter_238", "name": "BP"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_303", "name": "NMHC"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_318", "name": "THC"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}]}, {"station_id": "site_124", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_303", "name": "NMHC"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_315", "name": "SPM"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_232", "name": "Toluene"}]}, {"station_id": "site_136", "parameters": [{"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1421", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_1426", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1433", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_105", "parameters": [{"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_251", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_232", "name": "Toluene"}]}, {"station_id": "site_1560", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5024", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_1399", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_263", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5238", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5550", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_5339", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5682", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5687", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_5694", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5699", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5702", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5707", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5714", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5719", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5721", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_147", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_1406", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5477", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5403", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5410", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5542", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5129", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5547", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5489", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5491", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5395", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_255", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5338", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5263", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5249", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5105", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_166", "parameters": [{"id": "parameter_203", "name": "CO"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5066", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5112", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_1437", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5124", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5270", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5092", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5023", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5458", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5465", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5345", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5340", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5453", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5460", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5042", "parameters": [{"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5275", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_5364", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5047", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5422", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5415", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5408", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_5390", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5554", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5484", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5472", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1401", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}]}, {"station_id": "site_274", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}]}, {"station_id": "site_5131", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1557", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_293", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}]}, {"station_id": "site_1538", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5446", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}]}, {"station_id": "site_5600", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5597", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1418", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5592", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5054", "parameters": [{"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5650", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5073", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}]}, {"station_id": "site_5655", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5585", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5662", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5605", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5624", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5612", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5667", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_5674", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_1432", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_161", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_116", "parameters": [{"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_320", "name": "MH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_328", "name": "HCHO"}, {"id": "parameter_329", "name": "Hg"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}]}, {"station_id": "site_159", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_104", "parameters": [{"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1425", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_109", "parameters": [{"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_111", "parameters": [{"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_301", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1420", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_306", "parameters": [{"id": "parameter_238", "name": "BP"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_318", "name": "THC"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_262", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_298", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1393", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5679", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5686", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5693", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_1398", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1569", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5701", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5706", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}]}, {"station_id": "site_5713", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5718", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5720", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5725", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_305", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5065", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5104", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5267", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5274", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_1392", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1397", "parameters": [{"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5250", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5255", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_158", "parameters": [{"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5072", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5452", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_261", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5464", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5457", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5344", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_5363", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5407", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}]}, {"station_id": "site_5399", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5394", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5375", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5421", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5414", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5041", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5433", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5419", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5039", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5123", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_153", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5476", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5483", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5469", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_134", "parameters": [{"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5128", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_292", "parameters": [{"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_1549", "parameters": [{"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5111", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5248", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1556", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5053", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5262", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5370", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5490", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5337", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_237", "name": "SR"}]}, {"station_id": "site_1400", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}]}, {"station_id": "site_5402", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1405", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5109", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5541", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5553", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5546", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_5628", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5591", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_1450", "parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5604", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5584", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5596", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5539", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_204", "name": "AT"}]}, {"station_id": "site_1551", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_5661", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5659", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5654", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5611", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_146", "parameters": [{"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5060", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5046", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5623", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5503", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_5673", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_1563", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_115", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_202", "name": "Benzene"}]}, {"station_id": "site_254", "parameters": [{"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_122", "parameters": [{"id": "parameter_215", "name": "PM10"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_311", "name": "NH3"}]}, {"station_id": "site_103", "parameters": [{"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_108", "parameters": [{"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}]}, {"station_id": "site_273", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_232", "name": "Toluene"}]}, {"station_id": "site_297", "parameters": [{"id": "parameter_198", "name": "Temp"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_303", "name": "NMHC"}, {"id": "parameter_318", "name": "THC"}, {"id": "parameter_222", "name": "Ozone"}]}, {"station_id": "site_1424", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}]}, {"station_id": "site_1429", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_1431", "parameters": [{"id": "parameter_204", "name": "AT"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_165", "parameters": [{"id": "parameter_238", "name": "BP"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_303", "name": "NMHC"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_318", "name": "THC"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_198", "name": "Temp"}]}, {"station_id": "site_5678", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5680", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_238", "name": "BP"}]}, {"station_id": "site_5666", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5685", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5692", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}]}, {"station_id": "site_5700", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5705", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_300", "parameters": [{"id": "parameter_313", "name": "CH4"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_312", "name": "SO2"}]}, {"station_id": "site_5712", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5717", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}, {"station_id": "site_5724", "parameters": [{"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_194", "name": "NO2"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_223", "name": "Xylene"}]}], "all_parameters": [{"id": "parameter_194", "name": "NO2"}, {"id": "parameter_311", "name": "NH3"}, {"id": "parameter_225", "name": "NOx"}, {"id": "parameter_226", "name": "NO"}, {"id": "parameter_312", "name": "SO2"}, {"id": "parameter_203", "name": "CO"}, {"id": "parameter_222", "name": "Ozone"}, {"id": "parameter_193", "name": "PM2.5"}, {"id": "parameter_215", "name": "PM10"}, {"id": "parameter_202", "name": "Benzene"}, {"id": "parameter_198", "name": "Temp"}, {"id": "parameter_235", "name": "RH"}, {"id": "parameter_238", "name": "BP"}, {"id": "parameter_232", "name": "Toluene"}, {"id": "parameter_216", "name": "Eth-Benzene"}, {"id": "parameter_233", "name": "WS"}, {"id": "parameter_234", "name": "WD"}, {"id": "parameter_204", "name": "AT"}, {"id": "parameter_223", "name": "Xylene"}, {"id": "parameter_240", "name": "MP-Xylene"}, {"id": "parameter_237", "name": "SR"}, {"id": "parameter_37", "name": "TOT-RF"}, {"id": "parameter_236", "name": "RF"}, {"id": "parameter_241", "name": "O Xylene"}, {"id": "parameter_239", "name": "VWS"}, {"id": "parameter_324", "name": "P-Xylene"}, {"id": "parameter_313", "name": "CH4"}, {"id": "parameter_303", "name": "NMHC"}, {"id": "parameter_318", "name": "THC"}, {"id": "parameter_200", "name": "Gust"}, {"id": "parameter_201", "name": "Variance"}, {"id": "parameter_207", "name": "PP Accum"}, {"id": "parameter_192", "name": "Power"}, {"id": "parameter_217", "name": "CO2"}, {"id": "parameter_190", "name": "Black Carbon"}, {"id": "parameter_315", "name": "SPM"}, {"id": "parameter_320", "name": "MH"}, {"id": "parameter_328", "name": "HCHO"}, {"id": "parameter_329", "name": "Hg"}], "status": "success"}'

# %%
import json

# %%
json.dumps(raw_data)
# Out:
# '"{\\"cities\\": [{\\"stateName\\": \\"Karnataka\\", \\"citiesInState\\": [{\\"name\\": \\"Bagalkot\\", \\"live\\": true}, {\\"name\\": \\"Belgaum\\", \\"live\\": true}, {\\"name\\": \\"Bengaluru\\", \\"live\\": true}, {\\"name\\": \\"Bidar\\", \\"live\\": true}, {\\"name\\": \\"Chamarajanagar\\", \\"live\\": true}, {\\"name\\": \\"Chikkaballapur\\", \\"live\\": true}, {\\"name\\": \\"Chikkamagaluru\\", \\"live\\": true}, {\\"name\\": \\"Davanagere\\", \\"live\\": true}, {\\"name\\": \\"Dharwad\\", \\"live\\": true}, {\\"name\\": \\"Gadag\\", \\"live\\": true}, {\\"name\\": \\"Hassan\\", \\"live\\": true}, {\\"name\\": \\"Haveri\\", \\"live\\": true}, {\\"name\\": \\"Hubballi\\", \\"live\\": true}, {\\"name\\": \\"Kalaburagi\\", \\"live\\": true}, {\\"name\\": \\"Kolar\\", \\"live\\": true}, {\\"name\\": \\"Koppal\\", \\"live\\": true}, {\\"name\\": \\"Madikeri\\", \\"live\\": true}, {\\"name\\": \\"Mangalore\\", \\"live\\": true}, {\\"name\\": \\"Mysuru\\", \\"live\\": true}, {\\"na
# ...
