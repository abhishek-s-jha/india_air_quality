# %%
import pandas as pd

# %%
# %config Completer.use_jedi =False

# %%
df = pd.read_csv("./dataset_/Assam/Guwahati/site_5073.csv", index_col=0)

# %%
df
# Out:
#                  From Date              To Date  PM2.5 (ug/m3)  PM10 (ug/m3)  \
# 0      18-Feb-2019 - 00:00  18-Feb-2019 - 01:00          58.04         81.06
# 1      18-Feb-2019 - 01:00  18-Feb-2019 - 02:00          60.00         82.39
# 2      18-Feb-2019 - 02:00  18-Feb-2019 - 03:00          55.50         73.42
# 3      18-Feb-2019 - 03:00  18-Feb-2019 - 04:00          66.56         96.04
# 4      18-Feb-2019 - 04:00  18-Feb-2019 - 05:00          67.08         97.21
# ...                    ...                  ...            ...           ...
# 26921  15-Mar-2022 - 17:00  15-Mar-2022 - 18:00          90.25        160.78
# 26922  15-Mar-2022 - 18:00  15-Mar-2022 - 19:00         116.00        243.08
# 26923  15-Mar-2022 - 19:00  15-Mar-2022 - 20:00         190.25        336.25
# 26924  15-Mar-2022 - 20:00  15-Mar-2022 - 21:00         238.93        464.43
# 26925  15-Mar-2022 - 21:00  15-Mar-2022 - 22:00         237.36        486.14
#
# ...

# %%
df.columns
# Out:
# Index(['From Date', 'To Date', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)',
#        'AT (degree C)', 'SR (W/mt2)', 'RH (%)', 'WS (m/s)', 'WD (degree)',
#        'BP (mmHg)', 'RF (mm)', 'SO2 (ug/m3)', 'NO (ug/m3)', 'NO2 (ug/m3)',
#        'NOx (ppb)', 'NH3 (ug/m3)', 'CO (mg/m3)', 'Ozone (ug/m3)',
#        'Benzene (ug/m3)', 'Eth-Benzene (ug/m3)', 'MP-Xylene (ug/m3)',
#        'O Xylene (ug/m3)', 'Toluene (ug/m3)', 'TOT-RF (mm)'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PM2.5 (ug/m3)  PM10 (ug/m3)  AT (degree C)    SR (W/mt2)        RH (%)  \
# count   25550.000000  25982.000000   25419.000000  16355.000000  25485.000000
# mean       63.890467    122.558215      24.273417    239.222851     77.299692
# std        68.923175    133.310306       5.192655    239.629934     14.497032
# min         0.060000      0.500000       9.000000      0.080000     11.000000
# 25%        18.780000     34.442500      20.710000     12.145000     68.070000
# 50%        39.770000     73.970000      25.060000    160.560000     80.530000
# 75%        87.120000    162.912500      27.980000    427.580000     89.060000
# max       923.080000   1000.000000      37.640000    923.260000     99.000000
#
#            WS (m/s)   WD (degree)     BP (mmHg)       RF (mm)   SO2 (ug/m3)  \
# count  25440.000000  25485.000000  16073.000000  26490.000000  26467.000000
# mean       1.103430    152.132626    966.368652      0.077113     18.450358
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26926 entries, 0 to 26925
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   From Date            26926 non-null  object
#  1   To Date              26926 non-null  object
#  2   PM2.5 (ug/m3)        25550 non-null  float64
#  3   PM10 (ug/m3)         25982 non-null  float64
#  4   AT (degree C)        25419 non-null  float64
#  5   SR (W/mt2)           16355 non-null  float64
#  6   RH (%)               25485 non-null  float64
#  7   WS (m/s)             25440 non-null  float64
#  8   WD (degree)          25485 non-null  float64
#  9   BP (mmHg)            16073 non-null  float64
#  10  RF (mm)              26490 non-null  float64
#  11  SO2 (ug/m3)          26467 non-null  float64
#  12  NO (ug/m3)           25271 non-null  float64
#  13  NO2 (ug/m3)          26268 non-null  float64
#  14  NOx (ppb)            26490 non-null  float64
# ...
